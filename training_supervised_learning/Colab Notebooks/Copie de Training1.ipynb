# %%
import torch

if(torch.cuda.is_available()):
    dev = torch.device("cuda")
else:
    dev = torch.device("cpu")
print(dev)
# Out:
# cuda

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks')
import getdata
import training
# Out:
# Mounted at /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# cuda

# %%
trainset = getdata.get_data()
# Out:
# 17841
# 100429
# 172733
# 417196
# 643632
# 748103
# 2814188
# 4829088

# %%
from models import Net12RD

net = Net12RD()
net = net.to(dev)

# %%
training.train_model(net, trainset, save_file = "/content/drive/MyDrive/Model/NET12RD", batch_size = 64)
# Out:
# [1,   200] loss: 2.144
# [1,   400] loss: 2.037
# [1,   600] loss: 2.010
# [1,   800] loss: 1.973
# [1,  1000] loss: 1.917
# [1,  1200] loss: 1.896
# [1,  1400] loss: 1.864
# [1,  1600] loss: 1.828
# [1,  1800] loss: 1.829
# [1,  2000] loss: 1.787
# [1,  2200] loss: 1.771

# %%
training.train_model_load(net, trainset, save_file = "/content/drive/MyDrive/Model/NET12RD", batch_size = 100, lr = 0.00001)
# Out:
# [1,   200] loss: 1.428
# [1,   400] loss: 1.417
# [1,   600] loss: 1.413
# [1,   800] loss: 1.419
# [1,  1000] loss: 1.403
# [1,  1200] loss: 1.417
# [1,  1400] loss: 1.403
# [1,  1600] loss: 1.409
# [1,  1800] loss: 1.405
# [1,  2000] loss: 1.391
# [1,  2200] loss: 1.398
# [1,  2400] loss: 1.400
# [1,  2600] loss: 1.406
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-709b6a6a05f2> in <cell line: 1>()
# ----> 1 training.train_model_load(net, trainset, save_file = "/content/drive/MyDrive/Model/NET12RD", batch_size = 100, lr = 0.00001)
#
# /content/drive/MyDrive/Colab Notebooks/training.py in train_model_load(net, trainset, save_file, dev, saves, prints, lr, iter, batch_size, num_workers)
#     105           optimizer.step()
#     106
# --> 107           running_loss += loss.item()
# ...
