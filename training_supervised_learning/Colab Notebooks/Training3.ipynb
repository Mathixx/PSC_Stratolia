# %%
import torch

if(torch.cuda.is_available()):
    dev = torch.device("cuda")
else:
    dev = torch.device("cpu")
print(dev)
# Out:
# cuda

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks')
from models import Net12RDShallow
import getdata
import training
# Out:
# Mounted at /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# cuda

# %%
trainset = getdata.get_data()
# Out:
# 17841
# 100429
# 172733
# 417196
# 643632
# 748103
# 2814188
# 4829088

# %%
net = Net12RDShallow()
net = net.to(dev)
# Out:
# /content/drive/MyDrive/Colab Notebooks/models.py:347: UserWarning: nn.init.xavier_normal is now deprecated in favor of nn.init.xavier_normal_.
#   nn.init.xavier_normal(l.weight)

# %%
training.train_model(net,trainset,save_file = "/content/drive/MyDrive/Model/Net12RDShallow", batch_size = 100, lr = 0.0001)
# Out:
# [1,   200] loss: 2.265
# [1,   400] loss: 2.143
# [1,   600] loss: 2.052
# [1,   800] loss: 2.004
# [1,  1000] loss: 1.964
# [1,  1200] loss: 1.937
# [1,  1400] loss: 1.925
# [1,  1600] loss: 1.898
# [1,  1800] loss: 1.901
# [1,  2000] loss: 1.888
# [1,  2200] loss: 1.870
# [1,  2400] loss: 1.875
# [1,  2600] loss: 1.869
# [1,  2800] loss: 1.861
# [1,  3000] loss: 1.852
# [1,  3200] loss: 1.844
# [1,  3400] loss: 1.837
# [1,  3600] loss: 1.804
# [1,  3800] loss: 1.779
# [1,  4000] loss: 1.764
# [1,  4200] loss: 1.744
# [1,  4400] loss: 1.701
# [1,  4600] loss: 1.687
# [1,  4800] loss: 1.676
# [1,  5000] loss: 1.653
# [1,  5200] loss: 1.639
# [1,  5400] loss: 1.624
# [1,  5600] loss: 1.613
# [1,  5800] loss: 1.601
# [1,  6000] loss: 1.596
# [1,  6200] loss: 1.590
# [1,  6400] loss: 1.576
# [1,  6600] loss: 1.574
# [1,  6800] loss: 1.565
# [1,  7000] loss: 1.558
# [1,  7200] loss: 1.548
# [1,  7400] loss: 1.544
# [1,  7600] loss: 1.550
# [1,  7800] loss: 1.527
# [1,  8000] loss: 1.529
# ...

# %%
training.train_model_load(net,trainset,save_file = "/content/drive/MyDrive/Model/Net12RDShallow", batch_size = 100, lr = 0.00001)
# Out:
# [1,   200] loss: 1.382
# [1,   400] loss: 1.372
# [1,   600] loss: 1.370
# [1,   800] loss: 1.371
# [1,  1000] loss: 1.361
# [1,  1200] loss: 1.353
# [1,  1400] loss: 1.347
# [1,  1600] loss: 1.363
# [1,  1800] loss: 1.353
# [1,  2000] loss: 1.348
# [1,  2200] loss: 1.355
# [1,  2400] loss: 1.351
# [1,  2600] loss: 1.355
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-1e08ba833ec3> in <cell line: 1>()
# ----> 1 training.train_model_load(net,trainset,save_file = "/content/drive/MyDrive/Model/Net12RDShallow", batch_size = 100, lr = 0.00001)
#
# /content/drive/MyDrive/Colab Notebooks/training.py in train_model_load(net, trainset, save_file, dev, saves, prints, lr, iter, batch_size, num_workers)
#     105           optimizer.step()
#     106
# --> 107           running_loss += loss.item()
# ...
